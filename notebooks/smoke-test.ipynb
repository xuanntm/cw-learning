# %% [markdown]
# # Smoke test
#
# Confirms the `cw-learning` conda environment (Python + pandas) runs correctly from a notebook. Safe to delete once verified.

# %%
import sys
import pandas as pd

print(sys.version)
print("pandas", pd.__version__)

df = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})
df
# Out:
# 3.11.16 | packaged by conda-forge | (main, Aug 21 2026, 22:37:11) [MSC v.1944 64 bit (AMD64)]
# pandas 3.0.5
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
